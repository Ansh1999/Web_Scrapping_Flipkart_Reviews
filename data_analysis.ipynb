# %%
import pandas as pd

df = pd.read_csv("/Users/anshulmehra/WEB_SCRAPING/data/Redmi 10.csv")
df.drop('Unnamed: 0',axis=1,inplace=True)
df
# Out:
#     Product               Name  Rating            CommentHead  \
# 0  redmi 10  Flipkart customer       4            Pretty good
# 1  redmi 10      Aakash biswas       5  Mind-blowing purchase
# 2  redmi 10      Yogesh raghav       3           Does the job
# 3  redmi 10     Sumit banerjee       3         Decent product
# 4  redmi 10   Dhamchelam dukpa       5               Terrific
# 5  redmi 10     Basudeb  sahoo       5                Awesome
# 6  redmi 10   Nishant katalkar       5              Excellent
# 7  redmi 10  Flipkart customer       5         Simply awesome
# 8  redmi 10       Pravin awate       4            Bad quality
# 9  redmi 10       Dipankar roy       4        Value-for-money
#
#                                              Comment
# 0  After 14 days from buying this product,  I gav...
# 1  • Value for money Product.• Good Battery Life....
# 2  50mp based on 2005 times like 2 maga pixel 😂😂😂...
# 3  Extremely Big phone with average build quality...
# ...

# %%
dff = pd.read_csv("/Users/anshulmehra/WEB_SCRAPING/data/Iphone 14.csv")
dff.drop('Unnamed: 0',axis=1,inplace=True)
dff
# Out:
#      Product               Name  Rating          CommentHead  \
# 0  iphone 14      Rahul prasad        5            Fabulous!
# 1  iphone 14  Flipkart customer       5        Great product
# 2  iphone 14  Flipkart customer       5  Best in the market!
# 3  iphone 14      Feecon behera       5            Must buy!
# 4  iphone 14  Samaresh  tikader       5            Fabulous!
# 5  iphone 14      Kunal dhamija       5       Classy product
# 6  iphone 14   Manish choudhary       5     Perfect product!
# 7  iphone 14     Ashutosh kumar       5       Classy product
# 8  iphone 14         Afzal khan       5            Fabulous!
# 9  iphone 14      Sunder singh        5   Highly recommended
#
#                                              Comment
# 0  Best smart phone under this price range compar...
# 1  Damn such a great phone. Camera is really good...
# 2  Excellent smart phone, Good battery backup and...
# 3  Just awesome!!I switch to iPhone 14 from iPhon...
# ...
